# %%
# !pip install ultralytics roboflow
# Out:
# Requirement already satisfied: ultralytics in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (8.3.234)
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (3.10.7)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (2.9.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (0.24.1)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: polars>=0.20.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: certifi in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from roboflow) (2025.11.12)
# Collecting idna==3.7 (from roboflow)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from roboflow) (1.4.9)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp313-cp313-win_amd64.whl.metadata (6.7 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp313-cp313-win_amd64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: six in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from roboflow) (2.5.0)
# Collecting tqdm>=4.41.0 (from roboflow)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting requests-toolbelt (from roboflow)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: polars-runtime-32==1.35.2 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: filelock in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6)
# Requirement already satisfied: jinja2 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.12.0)
# Requirement already satisfied: setuptools in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ryany\onedrive\desktop\socceranalytics\venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading roboflow-1.2.11-py3-none-any.whl (89 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Downloading pi_heif-1.1.1-cp313-cp313-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/1.9 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 1.6/1.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 3.5 MB/s  0:00:00
# Downloading pillow_avif_plugin-1.5.2-cp313-cp313-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 4.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.9 MB 4.2 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.9 MB 4.1 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.9 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.9 MB 4.0 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.9 MB 4.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.9 MB 4.0 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.9 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.9 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 4.0 MB/s  0:00:02
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, tqdm, python-dotenv, pi-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#
#    ---------------------------------------- 0/9 [pillow-avif-plugin]
#    ---- ----------------------------------- 1/9 [filetype]
#    ---- ----------------------------------- 1/9 [filetype]
#    ---- ----------------------------------- 1/9 [filetype]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    -------- ------------------------------- 2/9 [tqdm]
#    ------------- -------------------------- 3/9 [python-dotenv]
#    ------------- -------------------------- 3/9 [python-dotenv]
#    ----------------- ---------------------- 4/9 [pi-heif]
#    ----------------- ---------------------- 4/9 [pi-heif]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#   Attempting uninstall: idna
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#     Found existing installation: idna 3.11
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#     Uninstalling idna-3.11:
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#       Successfully uninstalled idna-3.11
#    ---------------------- ----------------- 5/9 [opencv-python-headless]
#    -------------------------- ------------- 6/9 [idna]
#    -------------------------- ------------- 6/9 [idna]
#    -------------------------- ------------- 6/9 [idna]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ------------------------------- -------- 7/9 [requests-toolbelt]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ----------------------------------- ---- 8/9 [roboflow]
#    ---------------------------------------- 9/9 [roboflow]
#
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-avif-plugin-1.5.2 python-dotenv-1.2.1 requests-toolbelt-1.0.0 roboflow-1.2.11 tqdm-4.67.1
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="bnI0yJuJGLUrc9fAZwNo")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch:: 100%|██████████| 148663/148663 [00:41<00:00, 3567.87it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:01<00:00, 1071.14it/s]

# %%
dataset.location
# Out:
# 'c:\\Users\\ryany\\OneDrive\\Desktop\\socceranalytics\\training\\football-players-detection-1'

# %%
import shutil

shutil.move('football-players-detection-1/train',
             'football-players-detection-1/football-players-detection-1/train')

shutil.move('football-players-detection-1/test',
             'football-players-detection-1/football-players-detection-1/test')

shutil.move('football-players-detection-1/valid',
             'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5m.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ^C
